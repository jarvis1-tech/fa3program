# %% [markdown]
# <a href="https://colab.research.google.com/github/jarvis1-tech/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1
name = input("What is your name? ")
age = input("How old are you? ")
course = input("What is your course? ")
print("Name : ",name)
print("Age : ",age)
print("Course : ",course)

# %%
#fa3prog2
examscore = input("Input student exam score ")
if int(examscore) >= 75:
  print("Student passed")
else:
  print("Student failed")

# %%
#fa3prog3
name = input("Input name: ")
some_score = input("Input score: ")
score = int(some_score)

if score > 90:
  print("A")
elif score >= 80:
  print("B")
elif score >= 70:
  print("C")
else:
  print("F")
